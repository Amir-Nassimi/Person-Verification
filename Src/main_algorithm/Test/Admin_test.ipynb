# %%
import os
os.chdir('../../../../')

from PIL import Image
from person_verification.Src.main_algorithm.Codes.AdminModule import AdminModule

# %%
adrs = 'person_verification/Src/main_algorithm/Test/people/'
images = os.listdir(adrs)

list_of_dic = []
for idx, myimg in enumerate(images):
    list_of_dic.append({'image': [Image.open(adrs + myimg), Image.open(adrs + myimg), Image.open(adrs + myimg), Image.open(adrs + myimg)],
                        'username': 'Mr. ' + str(idx)})

# %%
images
# Out:
# ['0 (2).jpg',
#  '0 (4).jpg',
#  '0 (5).jpg',
#  '0 (6).jpg',
#  '0 (7).jpg',
#  '0 (8).jpg',
#  '0 (9).jpg',
#  '0.jpg']

# %%
list_of_dic
# Out:
# [{'image': [<PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x640>,
#    <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x640>,
#    <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x640>,
#    <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x640>],
#   'username': 'Mr. 0'},
#  {'image': [<PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=349x477>,
#    <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=349x477>,
#    <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=349x477>,
#    <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=349x477>],
#   'username': 'Mr. 1'},
#  {'image': [<PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=363x476>,
#    <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=363x476>,
#    <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=363x476>,
#    <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=363x476>],
#   'username': 'Mr. 2'},
# ...

# %%
my_admin_class = AdminModule(face_detection_model_path='person_verification/Models/YOLOs/yolov8n-face.pt',
                             dictionary_image_key='image',
                             dictionary_ID_key='username')

# %%
main_dataset, inappropriate_format, no_face_index, multiple_face_index = my_admin_class.Create_dataset(list_of_dic)
# Out:
# 0: 640x640 1 face, 14.5ms
# Speed: 0.0ms preprocess, 14.5ms inference, 236.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 0.0ms
# Speed: 0.0ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 15.6ms
# Speed: 0.0ms preprocess, 15.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 15.6ms
# Speed: 0.0ms preprocess, 15.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# 0: 640x480 1 face, 96.6ms
# Speed: 0.0ms preprocess, 96.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 face, 15.6ms
# Speed: 0.0ms preprocess, 15.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 face, 15.6ms
# Speed: 0.0ms preprocess, 15.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 face, 15.6ms
# ...

# %%
main_dataset
# Out:
# [['Mr. 0',
#   [-1.469342827796936,
#    0.6659530997276306,
#    -0.4782103896141052,
#    0.524005651473999,
#    1.9533072710037231,
#    0.7330045104026794,
#    0.7553013563156128,
#    -0.618217945098877,
#    0.6847033500671387,
#    0.4719036817550659,
#    1.2959002256393433,
#    0.43789568543434143,
#    0.7647910714149475,
#    -0.685181200504303,
#    1.4840123653411865,
#    -1.357158899307251,
#    -0.5568952560424805,
#    -0.06989742815494537,
#    1.5786224603652954,
#    -0.6924457550048828,
#    -0.051538050174713135,
#    -0.17542344331741333,
#    0.16719864308834076,
#    -0.6269838213920593,
#    -0.2960604429244995,
#    -0.3013635277748108,
#    0.36842185258865356,
#    -0.19057078659534454,
#    -1.4195351600646973,
#    0.5239576101303101,
#    0.5071180462837219,
#    0.28145742416381836,
#    -0.3639005422592163,
#    1.3877449035644531,
#    0.1654702126979828,
#    -1.0822474956512451,
#    0.1008313000202179,
#    1.5973294973373413,
# ...

# %%
inappropriate_format
# Out:
# []

# %%
no_face_index
# Out:
# []

# %%
multiple_face_index
# Out:
# []
